# %%
# !pip install -U ipykernel
# Out:
# Requirement already up-to-date: ipykernel in /usr/local/lib/python3.6/dist-packages (5.4.0)
# ...

# %%
# !pip install -q streamlit

# %%
# !pip install pyngrok

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install streamlit

# !pip install pyngrok

# %%
# %%writefile app.py

import streamlit as st
import numpy as np
from PIL import Image
import pickle as pk
import tensorflow as tf
from keras.models import Sequential
from keras.models import load_model
import cv2
 
def predict_catagory(img, models):
    img = cv2.resize(img,(100,100))
    img = np.array([img]) 
    output = sum([model.predict(img)[0][0] for model in models])/len(models)

    if output == 1:
        return "Infected"
    else:
        return "Un-Infected"
        
    #output = np.divide(np.sum(output[0],output[1]),2)
    
    return output
                
def main():
    
    custom_model = load_model(r'/content/drive/My Drive/Projects/malaria/custom_model.h5')
    
    vgg16_model = load_model(r'/content/drive/My Drive/Projects/malaria/malaria_VGGmodel.h5')
        
    models = [custom_model,vgg16_model]    
    
    st.title('''
             MALARIA DETECTION USING CNN
             ''')
    
    st.text('''
            We looked at easy to build open-source techniques leveraging AI 
            which can give us state-of-the-art accuracy in detecting malaria 
            thus enabling AI for social good.

            ''')
            
    
    img_file = st.file_uploader(' Please Select Your Blood Serum Image ', 
                     type = ['jpg','png','bmp','tiff','gif','jpeg'])
    
    try:
        image = Image.open(img_file)
        img_data = np.asarray(image, dtype = 'uint8')
        st.image(image, channel = 'BGR', caption = 'Blood Sample of Subject ', width = 200)
        
        if st.button('Predict'):
            
            output = predict_catagory(img_data, models)
            st.success("The Output Label is &nbsp : &nbsp {} :sunglasses:".format(output))
        
    
    except AttributeError:
        pass

if __name__=='__main__':
    main()
# Out:
# Overwriting app.py

# %%
# !ls
# Out:
# app.py	drive  sample_data

# %%
from pyngrok import ngrok

# %%
# Setup a tunnel to the streamlit port 8501
public_url = ngrok.connect(port='80')
public_url
# Out:
# <NgrokTunnel: "http://56728860bc15.ngrok.io" -> "http://localhost:80">

# %%
# !streamlit run --server.port 80 app.py >/dev/null
# Out:
# 2020-12-13 11:32:13.185642: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-13 11:32:14.795988: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-13 11:32:14.806277: E tensorflow/stream_executor/cuda/cuda_driver.cc:314] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-12-13 11:32:14.806329: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (c7124313d867): /proc/driver/nvidia/version does not exist
# 2020-12-13 11:32:14.813822: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2300000000 Hz
# 2020-12-13 11:32:14.814077: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1fddb80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %%
from google.colab import drive
 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# Out:
# app.py	drive  sample_data

# %%
# !ngrok authtoken 1lSZg1HhkgMf2qeWrfcLQzMuZH2_2C6vSaTVXizACqcueqwq2
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# !ls
# Out:
# app.py	drive  sample_data

# %%
# !streamlit run app.py &>/dev/null&

# %%
from pyngrok import ngrok
 
url = ngrok.connect(port = '8501')
url
# Out:
# <NgrokTunnel: "http://4fad7b86e26e.ngrok.io" -> "http://localhost:80">

# %%
# !pgrep streamlit
# Out:
# 366
